# %% [markdown]
# <a href="https://colab.research.google.com/github/bharrislife/for_family/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I am choosing Lane 1: CTR / Engagement Opportunity Scoring for my project lane. Based on our early discovery work, click-through rates are highly sensitive to both the search ranking position and the type of content being served. This lane is worth pursuing for the next 7 weeks because optimizing CTR directly influences organic search visibility and user engagement without needing to blindly guess how search algorithms shift.
# Out:
#   File "/tmp/ipykernel_1065/579000622.py", line 1
#     I am choosing Lane 1: CTR / Engagement Opportunity Scoring for my project lane. Based on our early discovery work, click-through rates are highly sensitive to both the search ranking position and the type of content being served. This lane is worth pursuing for the next 7 weeks because optimizing CTR directly influences organic search visibility and user engagement without needing to blindly guess how search algorithms shift.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
- Decision improved: This work improves the decision of how content development resources are allocated (e.g., whether to spend time creating video elements, restructuring articles, or adjusting metadata).
- Who acts on it: Content strategy managers and technical SEO engineers act on these insights.
- Cost of a wrong call: A wrong recommendation costs engineering and creative hours. If the model miscalculates and advises a massive content rewrite that drops the click-through rate, the company loses organic traffic and potentially misses out on revenue-generating user clicks.
# Out:
#   File "/tmp/ipykernel_1065/3403804183.py", line 1
#     - Decision improved: This work improves the decision of how content development resources are allocated (e.g., whether to spend time creating video elements, restructuring articles, or adjusting metadata).
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter data
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: Total rows/records available to learn from
total_rows = df.shape[0]

# Number 2: Baseline average CTR across the dataset
avg_ctr = df['ctr'].mean()

# Number 3: Total impressions tracked in this sample
total_impressions = df['impressions_90d'].sum()

print(f"1. Dataset Scale: {total_rows} total rows to analyze.")
print(f"2. Baseline performance: Average CTR is {avg_ctr:.4f} ({avg_ctr*100:.2f}%).")
print(f"3. Traffic Volume: {total_impressions:,} total impressions observed.")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
- What I CAN claim: I can point out observed historical patterns, identify directional trends (e.g., whether specific content types see better CTR inside certain position brackets), and provide actionable decision-support metrics for the content team.
- What I CANNOT claim: I will never claim causal proof or state that I am "predicting Google's secret ranking algorithm." This model measures correlation in our observed performance data, not a definitive map of external search engine logic.
# Out:
#   File "/tmp/ipykernel_1065/2132797669.py", line 1
#     - What I CAN claim: I can point out observed historical patterns, identify directional trends (e.g., whether specific content types see better CTR inside certain position brackets), and provide actionable decision-support metrics for the content team.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
